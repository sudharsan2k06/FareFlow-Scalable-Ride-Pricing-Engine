# %%
import pandas as pd

# %%
input_file = "../data/raw/splits/nyc_part_1.parquet"

# %%
df=pd.read_parquet(input_file)
df.shape
# Out:
# (2097152, 25)

# %%
df.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0005               B03406                 None
# 4            HV0005               B03406                 None
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2026-01-01 00:50:37 2026-01-01 00:52:31 2026-01-01 00:54:30
# 1 2026-01-01 00:09:12 2026-01-01 00:12:17 2026-01-01 00:12:39
# 2 2026-01-01 00:16:16 2026-01-01 00:29:33 2026-01-01 00:31:34
# 3 2026-01-01 00:08:19 2026-01-01 00:09:08 2026-01-01 00:09:37
# 4 2026-01-01 00:21:16 2026-01-01 00:26:30 2026-01-01 00:26:40
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  \
# 0 2026-01-01 01:13:23           262            79       4.300  ...
# 1 2026-01-01 00:22:42           195            52       1.890  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2097152 entries, 0 to 2097151
# Data columns (total 25 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   hvfhs_license_num     object
#  1   dispatching_base_num  object
#  2   originating_base_num  object
#  3   request_datetime      datetime64[us]
#  4   on_scene_datetime     datetime64[us]
#  5   pickup_datetime       datetime64[us]
#  6   dropoff_datetime      datetime64[us]
#  7   PULocationID          int32
#  8   DOLocationID          int32
#  9   trip_miles            float64
#  10  trip_time             int64
#  11  base_passenger_fare   float64
#  12  tolls                 float64
#  13  bcf                   float64
#  14  sales_tax             float64
#  15  congestion_surcharge  float64
#  16  airport_fee           float64
#  17  tips                  float64
#  18  driver_pay            float64
#  19  shared_request_flag   object
#  20  shared_match_flag     object
# ...

# %%
## Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PULocationID, DOLocationID, trip_miles, trip_time, base_passenger_fare, tolls, congestion_surcharge, airport_fee, tips, driver_pay, trip_minutes, trip_speed, pickup_hour, pickup_dayofweek, is_weekend]
# Index: []

# %%
df.isnull().sum().sum()
# Out:
# np.int64(576270)

# %%
df.isnull().any()
# Out:
# PULocationID            False
# DOLocationID            False
# trip_miles              False
# trip_time               False
# base_passenger_fare     False
# tolls                   False
# congestion_surcharge    False
# airport_fee             False
# tips                    False
# driver_pay              False
# trip_minutes            False
# trip_speed              False
# pickup_hour             False
# pickup_dayofweek        False
# is_weekend              False
# dtype: bool

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.isnull().sum()
# Out:
# request_datetime        0
# on_scene_datetime       0
# pickup_datetime         0
# dropoff_datetime        0
# PULocationID            0
# DOLocationID            0
# trip_miles              0
# trip_time               0
# base_passenger_fare     0
# tolls                   0
# congestion_surcharge    0
# airport_fee             0
# tips                    0
# driver_pay              0
# dtype: int64

# %%
df.head()
# Out:
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2026-01-01 00:50:37 2026-01-01 00:52:31 2026-01-01 00:54:30
# 1 2026-01-01 00:09:12 2026-01-01 00:12:17 2026-01-01 00:12:39
# 2 2026-01-01 00:16:16 2026-01-01 00:29:33 2026-01-01 00:31:34
# 3 2026-01-01 00:08:19 2026-01-01 00:09:08 2026-01-01 00:09:37
# 4 2026-01-01 00:21:16 2026-01-01 00:26:30 2026-01-01 00:26:40
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  trip_time  \
# 0 2026-01-01 01:13:23           262            79       4.300       1133
# 1 2026-01-01 00:22:42           195            52       1.890        604
# 2 2026-01-01 00:55:21            25           181       1.840       1427
# 3 2026-01-01 00:22:12           141           226       3.307        755
# 4 2026-01-01 00:39:06           226           226       2.060        746
#
#    base_passenger_fare  tolls  congestion_surcharge  airport_fee  tips  \
# 0                31.24    0.0                  2.75          0.0  0.00
# ...

# %%
df.to_parquet("../data/processed/clean_split_1.parquet", index=False)

# %%
##cleaning 2
input_file = "../data/raw/splits/nyc_part_2.parquet"
df=pd.read_parquet(input_file)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(543543)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.shape
# Out:
# (2097152, 14)

# %%
df.to_parquet("../data/processed/clean_split_2.parquet", index=False)

# %%
##cleaning 3
input_file = "../data/raw/splits/nyc_part_3.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.to_parquet("../data/processed/clean_split_3.parquet", index=False)

# %%
input_file = "../data/raw/splits/nyc_part_4.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.shape
# Out:
# (2097152, 14)

# %%
df.to_parquet("../data/processed/clean_split_4.parquet", index=False)

# %%
##5!!
input_file = "../data/raw/splits/nyc_part_5.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.to_parquet("../data/processed/clean_split_5.parquet", index=False)

# %%
##6!!
input_file = "../data/raw/splits/nyc_part_6.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.to_parquet("../data/processed/clean_split_6.parquet", index=False)

# %%
#7!!
input_file = "../data/raw/splits/nyc_part_7.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.to_parquet("../data/processed/clean_split_7.parquet", index=False)

# %%
#8!!
input_file = "../data/raw/splits/nyc_part_8.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.to_parquet("../data/processed/clean_split_8.parquet", index=False)

# %%
#9!!
input_file = "../data/raw/splits/nyc_part_9.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.shape
# Out:
# (2066005, 14)

# %%
df.to_parquet("../data/processed/clean_split_9.parquet", index=False)

# %%
#10!!
input_file = "../data/raw/splits/nyc_part_10.parquet"
df=pd.read_parquet(input_file)

# %%
columns_to_drop = [
    "originating_base_num",
    "hvfhs_license_num",
    "dispatching_base_num",
    "sales_tax",
    "bcf",
    "cbd_congestion_fee",
    "shared_request_flag",
    "shared_match_flag",
    "access_a_ride_flag",
    "wav_request_flag",
    "wav_match_flag"
]

df = df.drop(columns=columns_to_drop)

# %%
df.to_parquet("../data/processed/clean_split_10.parquet", index=False)
